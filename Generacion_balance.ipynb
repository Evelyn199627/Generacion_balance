# %% [markdown]
# <a href="https://colab.research.google.com/github/Evelyn199627/Generacion_balance/blob/main/Generacion_balance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_excel("/content/sample_data/Mayores-empresa.xlsx",sheet_name="Mayores")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#        FECHA  Mes  CODIGO NOMBRE DE CUENTA  ASIENTO  TIPO   IMPORTE      DEBE  \
# 0 2021-12-01   12  111101       CAJA PESOS   2314.0   2.0    440.53       NaN
# 1 2021-12-01   12  111101       CAJA PESOS   3231.0   1.0  13500.00  13500.00
# 2 2021-12-01   12  111101       CAJA PESOS  70645.0   1.0   1399.99   1399.99
# 3 2021-12-02   12  111101       CAJA PESOS   2344.0   2.0   1000.00       NaN
# 4 2021-12-06   12  111101       CAJA PESOS   2439.0   2.0    852.55       NaN
#
#      HABER  MOVIMIENTO  ...  OPERADOR    INGRESO      HORA  OPERACION EMPRESA  \
# 0   440.53     -440.53  ...  IPULICIC 2022-03-21  11:19:18   966769.0     0.0
# 1      NaN    13500.00  ...  JMONTEFI 2022-05-23  16:01:17   975738.0     0.0
# 2      NaN     1399.99  ...    DDENIS 2021-12-01  16:49:22   952448.0     0.0
# 3  1000.00    -1000.00  ...  IPULICIC 2022-03-21  11:19:18   966769.0     0.0
# 4   852.55     -852.55  ...  IPULICIC 2022-03-21  11:19:18   966769.0     0.0
#
# ...

# %%
ordenER = pd.read_excel("/content/sample_data/Mayores-empresa.xlsx",sheet_name="Orden ER")

# %%
ordenESP = pd.read_excel("/content/sample_data/Mayores-empresa.xlsx",sheet_name="Orden ESP")

# %%
plan_cuentas = pd.read_excel("/content/sample_data/Mayores-empresa.xlsx",sheet_name="Cuentas Pat y Rdo (2)")

# %%
df.dtypes

# %%
df["Periodo"]  = df.FECHA.dt.strftime("%m-%Y")
